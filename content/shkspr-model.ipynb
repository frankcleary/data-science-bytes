# %%
# %matplotlib inline
import nltk
from collections import defaultdict
from collections import Counter
from pprint import pprint
import matplotlib.pyplot as plt
from matplotlib import text

# %%
stopwords = set(nltk.corpus.stopwords.words('english'))

# %%
nltk.corpus.shakespeare.fileids()
# Out:
# ['a_and_c.xml',
#  'dream.xml',
#  'hamlet.xml',
#  'j_caesar.xml',
#  'macbeth.xml',
#  'merchant.xml',
#  'othello.xml',
#  'r_and_j.xml']

# %%
a_and_c = nltk.corpus.shakespeare.xml('hamlet.xml')

# %%
print nltk.corpus.shakespeare.raw('a_and_c.xml')
# Out:
# <?xml version="1.0"?>
# <?xml-stylesheet type="text/css" href="shakes.css"?>
# <!-- <!DOCTYPE PLAY SYSTEM "play.dtd"> -->
#
# <PLAY>
# <TITLE>The Tragedy of Antony and Cleopatra</TITLE>
# <!--
#
# <P>Text placed in the public domain by Moby Lexical Tools, 1992.</P>
# <P>XML markup by Jon Bosak, 1996-1998.</P>
# <P>XML Styling done by Ajay Juneja, 1999.<P>
# <P>This work may be freely copied and distributed worldwide.</P>
#
# -->
# <PERSONAE>
# <TITLE>Dramatis Personae</TITLE>
#
#
# <PGROUP>
# <PERSONA>MARK ANTONY</PERSONA>
# <PERSONA>OCTAVIUS CAESAR</PERSONA>
# <PERSONA>M. AEMILIUS LEPIDUS</PERSONA>
# <GRPDESCR>triumvirs.</GRPDESCR>
# </PGROUP>
#
# <PERSONA>SEXTUS POMPEIUS</PERSONA>
#
# <PGROUP>
# <PERSONA>DOMITIUS ENOBARBUS</PERSONA>
# <PERSONA>VENTIDIUS</PERSONA>
# <PERSONA>EROS</PERSONA>
# <PERSONA>SCARUS</PERSONA>
# <PERSONA>DERCETAS</PERSONA>
# <PERSONA>DEMETRIUS</PERSONA>
# <PERSONA>PHILO</PERSONA>
# <GRPDESCR>friends to Antony.</GRPDESCR>
# </PGROUP>
#
#
# <PGROUP>
# ...

# %%
lines = defaultdict(list)
linecounts = defaultdict(int)
tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
for file_id in nltk.corpus.shakespeare.fileids():
    raw_data = nltk.corpus.shakespeare.xml(file_id)
    for child in raw_data.findall('ACT/SCENE/SPEECH'):
        speaker = child.findall('SPEAKER')[0].text + ', ' + file_id
        try:
            for ele in child.findall('LINE'):
                if ele.text is not None:
                    for word in tokenizer.tokenize(ele.text):
                        if word.lower() not in stopwords and len(word) > 2:
                            lines[speaker].append(word.lower())
                            linecounts[speaker] += 1
        except AttributeError:
            pass

# %%
for speaker, count in linecounts.iteritems():
    print speaker, count
# Out:
# LUCILIUS, j_caesar.xml 90
# PROCULEIUS, a_and_c.xml 96
# First Apparition, macbeth.xml 10
# OCTAVIUS CAESAR, a_and_c.xml 1380
# Servant, macbeth.xml 11
# ANTONIO, merchant.xml 661
# DECIUS BRUTUS, j_caesar.xml 163
# GOBBO, merchant.xml 155
# GRATIANO, merchant.xml 679
# OBERON, dream.xml 883
# LEONARDO, merchant.xml 8
# Porter, macbeth.xml 145
# ARRAGON, merchant.xml 244
# Gentleman, hamlet.xml 99
# Fourth Soldier, a_and_c.xml 11
# Second Commoner, j_caesar.xml 70
# DEMETRIUS, a_and_c.xml 18
# SALERIO, merchant.xml 77
# CORNELIUS, hamlet.xml 3
# CALPURNIA, j_caesar.xml 103
# MACDUFF, macbeth.xml 626
# Servant, hamlet.xml 4
# LODOVICO, othello.xml 254
# THYREUS, a_and_c.xml 86
# MACBETH, macbeth.xml 2653
# LORD POLONIUS, hamlet.xml 1203
# Poet, j_caesar.xml 14
# CAITHNESS, macbeth.xml 38
# STARVELING, dream.xml 13
# CINNA THE POET, j_caesar.xml 49
# TITANIA, dream.xml 638
# Doctor, macbeth.xml 142
# CAESAR, j_caesar.xml 481
# MUSTARDSEED, dream.xml 3
# FLUTE, dream.xml 96
# ...

# %%
for speaker, words in lines.iteritems():
    print speaker
    print Counter(words).most_common(10)
    print '\n\n'
# Out:
# LUCILIUS, j_caesar.xml
# [('brutus', 6), ('thou', 4), ('alive', 2), ('kill', 2), ('cato', 2), ('enough', 2), ('honour', 2), ('noble', 2), ('thee', 2), ('safe', 2)]
#
#
#
# PROCULEIUS, a_and_c.xml
# [('shall', 5), ('caesar', 4), ('let', 3), ('lady', 3), ('report', 2), ('full', 2), ('find', 2), ('hold', 2), ('thee', 2), ('grace', 2)]
#
#
#
# First Apparition, macbeth.xml
# [('macbeth', 3), ('beware', 2), ('macduff', 1), ('fife', 1), ('thane', 1), ('enough', 1), ('dismiss', 1)]
#
#
#
# OCTAVIUS CAESAR, a_and_c.xml
# [('shall', 23), ('antony', 20), ('let', 14), ('thou', 11), ('make', 10), ('cleopatra', 9), ('good', 9), ('upon', 9), ('thy', 9), ('know', 9)]
#
#
#
# Servant, macbeth.xml
# [('madam', 2), ('force', 1), ('ten', 1), ('sir', 1), ('thousand', 1), ('english', 1), ('please', 1), ('returns', 1), ('night', 1), ('soldiers', 1)]
#
#
#
# ANTONIO, merchant.xml
# ...

# %%
from gensim import corpora, models, similarities

# %%
personae = [persona for persona in lines.keys() if linecounts[persona] > 100] # list of personae to garrantee order
line_list = [lines[persona] for persona in personae]
dictionary = corpora.Dictionary(line_list)
once_ids = [tokenid for tokenid, docfreq in dictionary.dfs.iteritems() if docfreq == 1]
dictionary.filter_tokens(once_ids)
dictionary.compactify()

# %%
corpus = [dictionary.doc2bow(words) for words in line_list]

# %%
tfidf = models.TfidfModel(corpus)

# %%
lsi = models.lsimodel.LsiModel(corpus=tfidf[corpus], id2word=dictionary, num_topics=4)

# %%
lsi.print_topics(5)[:3]
# Out:
# [u'-0.192*"caesar" + -0.125*"lord" + -0.121*"antony" + -0.112*"brutus" + -0.106*"thou" + -0.105*"romeo" + -0.093*"cassio" + -0.091*"love" + -0.084*"thee" + -0.078*"madam"',
#  u'-0.513*"caesar" + -0.378*"brutus" + -0.286*"antony" + -0.192*"cassius" + 0.151*"romeo" + -0.139*"rome" + 0.108*"cassio" + -0.090*"octavius" + -0.081*"lepidus" + 0.073*"tybalt"',
#  u'-0.459*"cassio" + 0.352*"romeo" + 0.170*"tybalt" + -0.164*"moor" + -0.164*"iago" + 0.124*"juliet" + 0.114*"nurse" + -0.111*"desdemona" + -0.105*"lord" + -0.104*"lieutenant"']

# %%
matsim = similarities.MatrixSimilarity(lsi[tfidf[corpus]])

# %%
plt.figure(figsize=(20, 20))
plt.matshow(matsim.index)
plt.xticks(xrange(len(personae)), personae, rotation=90)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0000000014BF02C8>

# %%
for persona, sims in zip(personae, matsim):
    sorted_sims = sorted(zip(personae, sims), key=lambda item: -item[1])
    print persona
    for other_persona, score in sorted_sims[:5]:
        if persona == other_persona:
            continue
        print '\t' + other_persona + ' ' + str(score)
# Out:
# OCTAVIUS CAESAR, a_and_c.xml
# 	CLEOPATRA, a_and_c.xml 0.99529
# 	MARK ANTONY, a_and_c.xml 0.992495
# 	LEPIDUS, a_and_c.xml 0.99033
# 	DOMITIUS ENOBARBUS, a_and_c.xml 0.985345
# ANTONIO, merchant.xml
# 	SHYLOCK, merchant.xml 0.998335
# 	DUKE, merchant.xml 0.997089
# 	GRATIANO, merchant.xml 0.996707
# 	PORTIA, merchant.xml 0.994586
# DECIUS BRUTUS, j_caesar.xml
# 	Servant, j_caesar.xml 0.996067
# 	ANTONY, j_caesar.xml 0.99444
# 	CAESAR, j_caesar.xml 0.993772
# 	TITINIUS, j_caesar.xml 0.991406
# GOBBO, merchant.xml
# 	PETER, r_and_j.xml 0.995156
# 	LAUNCELOT, merchant.xml 0.98936
# 	LORENZO, merchant.xml 0.988051
# 	BASSANIO, merchant.xml 0.986358
# GRATIANO, merchant.xml
# 	SHYLOCK, merchant.xml 0.999375
# 	DUKE, merchant.xml 0.997124
# 	ANTONIO, merchant.xml 0.996707
# 	SALARINO, merchant.xml 0.994973
# OBERON, dream.xml
# 	PUCK, dream.xml 0.990492
# 	THESEUS, dream.xml 0.986521
# 	BOTTOM, dream.xml 0.984401
# 	Fairy, dream.xml 0.98045
# Porter, macbeth.xml
# ...

# %%
a_and_c_words = Counter(lines['OCTAVIUS CAESAR, a_and_c.xml']).most_common(20)
jc_words = Counter(lines['CLEOPATRA, a_and_c.xml']).most_common(20)

# %%
set([pair[0] for pair in a_and_c_words]).intersection(set([pair[0] for pair in jc_words]))
# Out:
# {'antony',
#  'caesar',
#  'come',
#  'good',
#  'let',
#  'make',
#  'shall',
#  'thee',
#  'thou',
#  'thy'}

# %%
set([pair[0] for pair in jc_words]) - set([pair[0] for pair in a_and_c_words])
# Out:
# {'charmian',
#  'give',
#  'lord',
#  'mine',
#  'say',
#  'sir',
#  'tell',
#  'well',
#  'would',
#  'yet'}

# %%
lsi[tfidf[corpus[3]]]
# Out:
# [(0, -0.17907067116263742),
#  (1, 0.074843990053021781),
#  (2, 0.010216937560161472),
#  (3, 0.067090995257733405)]

# %%
def round_topic_coeffs(topic):
    return [('{0:.3f}'.format(coeff), word) for coeff, word in topic]

def plot_axes(x=0, y=1):
    x_data = defaultdict(list)
    y_data = defaultdict(list)
    chars = defaultdict(list)
    print 'x topic: {}'.format(round_topic_coeffs(lsi.show_topic(x)))
    print ''
    print 'y topic: {}'.format(round_topic_coeffs(lsi.show_topic(y)))
    for persona, doc in zip(personae, corpus):
        play = persona.split(', ')[1]
        x_data[play].append((lsi[tfidf[doc]][x][1]))
        y_data[play].append((lsi[tfidf[doc]][y][1]))
        chars[play].append(persona.split(', ')[0])
    plt.figure(figsize=(10, 10))
    ax = plt.gca()
    cmap = plt.get_cmap('Paired')
    play_index = {play: i for i, play in enumerate(nltk.corpus.shakespeare.fileids())}
    for play in play_index:
        color_index = play_index[play] / float(len(play_index))
        plt.scatter(x_data[play], y_data[play], color=cmap(color_index), label=play[:-4], alpha=.5, s=40)
        for char, x, y in zip(chars[play], x_data[play], y_data[play]):
            ax.annotate(char, xy=(x, y), xycoords='data', xytext=(1, 1), textcoords='offset points', size=10)
    plt.legend(ncol=4, scatterpoints=1)

# %%
plot_axes(x=2, y=3)
# Out:
# x topic: [('-0.459', u'cassio'), ('0.352', u'romeo'), ('0.170', u'tybalt'), ('-0.164', u'moor'), ('-0.164', u'iago'), ('0.124', u'juliet'), ('0.114', u'nurse'), ('-0.111', u'desdemona'), ('-0.105', u'lord'), ('-0.104', u'lieutenant')]
#
# y topic: [('-0.367', u'romeo'), ('0.253', u'hermia'), ('0.244', u'demetrius'), ('0.239', u'lysander'), ('-0.216', u'cassio'), ('-0.174', u'tybalt'), ('0.156', u'pyramus'), ('0.152', u'thisby'), ('0.132', u'helena'), ('-0.123', u'juliet')]

# %%
cmap = plt.get_cmap('Paired')
cmap(0)
# Out:
# (0.65098041296005249, 0.80784314870834351, 0.89019608497619629, 1.0)
