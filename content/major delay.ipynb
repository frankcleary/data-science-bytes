# %% [markdown]
# I recently starting collecting data from the [BART API](http://www.bart.gov/schedules/developers/api), specifically estimated departure times for trains at the two stations I use most frequently. In this notebook I'll show how I parsed the data from a csv and customized some plots by changing the linestype of a column to emphasize a special event.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import datetime

def prettify_axis(ax, ylabel='', xlabel=''):
    label_format_dict = dict(fontsize=20, fontweight='bold')
    tick_format_dict = dict(labelsize=16, direction='out', top='off', right='off', 
                            length=4, width=1)
    ax.set_xlabel(xlabel, label_format_dict)
    ax.set_ylabel(ylabel, label_format_dict)
    ax.tick_params(**tick_format_dict)

# %% [markdown]
# Here is the data:

# %%
# !head -n3 extra/data/plza.csv
# Out:
# time,dest,dir,len,etd
# 1417108837.85,Fremont,South,6,3
# 1417108837.85,Richmond,North,6,10

# %% [markdown]
# A custom date parsing funcion, which parses the timestamps into datetimes and converts them to Pacific time.

# %%
def parse_time(timestamp):
    try:
        dt = pd.to_datetime(float(timestamp), unit='s')
        return dt.tz_localize('UTC').tz_convert('US/Pacific')
    except AttributeError, ValueError:
        return pd.NaT

# %% [markdown]
# Reading in the data using the date parser defined above.

# %%
df = pd.read_csv('extra/data/plza.csv', parse_dates=['time'], date_parser=parse_time)
df['etd'] = df['etd'].replace('Leaving', 0).astype(np.float) 
df.head(3)
# Out:
#                                time      dest    dir  len  etd
# 0  2014-11-27 09:20:37.850000-08:00   Fremont  South    6    3
# 1  2014-11-27 09:20:37.850000-08:00  Richmond  North    6   10
# 2  2014-11-27 09:22:01.120000-08:00   Fremont  South    6    2

# %% [markdown]
# Filter the DataFrame to keep only at trains going to Millbrae.

# %%
df_mill = df[df['dest'] == 'Millbrae']
df_mill.head(3)
# Out:
#                                   time      dest    dir  len  etd
# 1992  2014-11-28 03:29:01.120000-08:00  Millbrae  South    5   52
# 1994  2014-11-28 03:30:01.460000-08:00  Millbrae  South    5   51
# 1996  2014-11-28 03:31:01.810000-08:00  Millbrae  South    5   50

# %% [markdown]
# To better understand my communte I want to look into the daily variability in estimated departure times. To do this I'll do a few transformations on the `time` column to extract the dates and the time of day, then use a pivot table to reshape the data.

# %%
pd.to_datetime(df['time']).resample('M').apply(lambda x: x.time())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-a8a54ec9e7fa> in <module>()
# ----> 1 pd.to_datetime(df['time']).resample('M').apply(lambda x: x.time())
#
# c:\Users\Frank\Anaconda\lib\site-packages\pandas\core\generic.pyc in resample(self, rule, how, axis, fill_method, closed, label, convention, kind, loffset, limit, base)
#    2878                               fill_method=fill_method, convention=convention,
#    2879                               limit=limit, base=base)
# -> 2880         return sampler.resample(self).__finalize__(self)
#    2881
#    2882     def first(self, offset):
#
# c:\Users\Frank\Anaconda\lib\site-packages\pandas\tseries\resample.pyc in resample(self, obj)
#     100             return self.obj
#     101         else:  # pragma: no cover
# --> 102             raise TypeError('Only valid with DatetimeIndex or PeriodIndex')
#     103
# ...

# %%
df_mill['time_of_day'] = df['time'].apply(lambda x: datetime.time(x.time().hour, x.time().minute))
df_mill['date'] = df['time'].apply(lambda x: x.date())
mill_pivot = df_mill.pivot(index='time_of_day', columns='date', values='etd')
mill_pivot.ix[:3, :4]
# Out:
# date         2014-11-28  2014-12-01  2014-12-02  2014-12-03
# time_of_day
# 03:29:00             52          52          52          52
# 03:30:00             51          51          51          51
# 03:31:00             50          50          50          50

# %% [markdown]
# Plotting the data.

# %%
ax = mill_pivot.plot(figsize=(16, 10), cmap='Paired', lw=2, alpha=.5, xlim=[datetime.time(5, 0), datetime.time(18, 0)])
prettify_axis(ax, xlabel='Time of day', ylabel='ETD of next train (minutes)')
plt.xticks([datetime.time(hour, minute) for minute in xrange(0, 60, 20) for hour in xrange(5, 18)], rotation=90);

# %%
for col in mill_pivot.columns:
    ax = pt.plot(figsize=(16, 10))
    prettify_axis(ax, xlabel='Time of Day', ylabel='ETD of next train (minutes)')
    ax.set_title(col)
    for lines in zip(ax.get_lines(), ax.get_legend().get_lines()):
        if lines[0].get_label() == str(col):
            plt.setp(lines, lw=2, zorder=0)
        else:
            plt.setp(lines, alpha=.5)

# %%
import time
x = df_mill[df_mill['etd'] == 0]['time'].apply(lambda x: x.time()).values
time.gmtime(x[1].time_tuple())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-417137c6e2fd> in <module>()
#       1 import time
#       2 x = df_mill[df_mill['etd'] == 0]['time'].apply(lambda x: x.time()).values
# ----> 3 time.gmtime(x[1].time_tuple())
#
# AttributeError: 'datetime.time' object has no attribute 'time_tuple'

# %%
df_mill[df_mill['timestr'] == '07:40']['etd'].hist()
